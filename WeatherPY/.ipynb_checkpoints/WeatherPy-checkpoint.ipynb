# %% [markdown]
# # Dependencies

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import requests
import time
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import linregress

# import API key
from config import API_Key

#Import citipy to collect latitude and longitudes of cities
from citipy import citipy

# Output File (CSV)
Output_Data_file = "../Output_Data/cities.csv"

# %% [markdown]
# # Create Randomized Cities List

# %%
# Set the ranges the latitude and longitudes
latitude_range = (-90, 90)
longitude_range = (-180, 180)

#Create holding placements for the cordinates and the cities you're making
coordinates = []
cities = []

#Set ranges for coordinates you generate
lat = np.random.uniform(low=-90.000, high=90.000, size=1500)
lng = np.random.uniform(low=-180.000, high=180.000, size=1500)
coordinates = zip(lat, lng)

# %%
#Connect the coordinates to the cities they match with
for coordinate in coordinates: 
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
     
    #sub in 20% to replace any spaces in the URL so it runs correctly
    city = city.replace(" ", "20%")
    
    #Remove duplicates = if the city is not duplicated add it to the list
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 623

# %%
#Start the URL for the Weather Map API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + API_Key

# %%
#Create lists to add the API data into
city_name = []
country = []
date = []
lat = []
lng = []
cloudiness = []
humidity = []
max_temp = []
wind_speed = []

# %% [markdown]
# # Create a For Loop to Pull Data for Each City
# ### (API Calls)

# %%
#API call counter
api_call_count = 1

#Display counter
print("------------------------------------")
print("Grabbing your info now! Please hold.")
print("------------------------------------")

#Go through the cities in the list and get the API data to fill
for city in cities:
    try: 
        response = requests.get(f"{url}&q={city}").json()
        
        city_name.append(response["name"])
        
        cloudiness.append(response["clouds"]["all"])
        
        country.append(response["sys"]["country"])
        
        date.append(response["dt"])
        
        humidity.append(response["main"]["humidity"])
        
        max_temp.append(response["main"]["temp_max"])
        
        lat.append(response["coord"]["lat"])
        
        lng.append(response["coord"]["lon"])
        
        wind_speed.append(response["wind"]["speed"])
        
        city_record = response["name"]
        
        print(f"Record {api_call_count}: {city_record}")
   

        #Add one to counter to make it cycle through for loop
        api_call_count= api_call_count + 1
    
        #Insert pace to the API calls so we don't get kicked out/banned
        time.sleep(1.01)
    
    
    #If there is no city, skip the line and go to the next one
    except:
        print("No city found for that listing. Moving onto the next.")
    continue
    
    print("-----------------------------")
    print("Data Retrieval Complete")
    print("-----------------------------")
# Out:
# ------------------------------------
# Grabbing your info now! Please hold.
# ------------------------------------
# No city found for that listing. Moving onto the next.
# Record 1: Qaanaaq
# Record 2: Morąg
# Record 3: Dikson
# Record 4: Beringovskiy
# Record 5: Castro
# Record 6: Kapaa
# No city found for that listing. Moving onto the next.
# Record 7: Flinders
# Record 8: Avera
# No city found for that listing. Moving onto the next.
# Record 9: Hong Kong
# Record 10: Ilulissat
# No city found for that listing. Moving onto the next.
# Record 11: Huarmey
# Record 12: George Town
# Record 13: Fortuna
# Record 14: Bredasdorp
# Record 15: Hilo
# Record 16: Aksarka
# No city found for that listing. Moving onto the next.
# Record 17: Severo-Kuril'sk
# Record 18: Maebaru-chūō
# No city found for that listing. Moving onto the next.
# No city found for that listing. Moving onto the next.
# Record 19: Rikitea
# Record 20: Ushuaia
# Record 21: Lincoln
# ...

# %% [markdown]
# # Turn Data from API into a DF

# %%
# Use the data from the API and put it into a dictionary, whilst turning that into a DF

# %%
weather_dict = pd.DataFrame({"City": city_name,
                             "Cloudiness": cloudiness,
                             "Country": country,
                             "Humidity": humidity,
                             "Lat": lat,
                             "Lng": lng,
                             "Max Temp": max_temp,
                             "Wind Speed": wind_speed})

# %%
#Display Dict as DF
weather_dict.head()
# Out:
#            City  Cloudiness Country  Humidity      Lat       Lng  Max Temp  \
# 0       Qaanaaq         100      GL        82  77.4840  -69.3632     -0.81
# 1         Morąg          71      PL        90  53.9171   19.9260     30.99
# 2        Dikson          92      RU       100  73.5069   80.5464     -7.33
# 3  Beringovskiy          10      RU        83  63.0500  179.3167      0.57
# 4        Castro          49      BR        94 -24.7911  -50.0119     59.20
#
#    Wind Speed
# 0        2.28
# 1        3.00
# 2        6.62
# 3        8.03
# 4        4.65

# %%
#Save city data into a csv file
weather_dict.to_csv("../Output_Data/weather.csv", index = False, header =True)

# %% [markdown]
# # Create Scatter Plots & Plot Data

# %%
#We will be creating scatter plots to represent the following data
# -Temperature (F) vs. Latitude
# -Humidity (%) vs. Latitude
# -Cloudiness (%) vs. Latitude
# -Wind Speed (mph) vs. Latitude

# %% [markdown]
# ### • Latitude vs. Temperature (F)

# %%
#Plot & Format Data
plt.scatter(weather_dict["Lat"], weather_dict["Max Temp"], facecolor = "mediumseagreen", edgecolor = "darkslategrey")

#Set All Labels
#Title
plt.title("City Latitude vs. Max Temperature")
#X Axis
plt.xlabel("City Latitude")
#Y Axis
plt.ylabel("Max Temperature (F)")

#Insert Gridlines
plt.grid(linestyle=":", linewidth=1, alpha=0.5)

#Save Graph as Image (PNG)
plt.savefig('../Images/Lat_VS_Temp.png')

# %% [markdown]
# #### Observations
#
# ##### This graph is observing the relationship between Latitude and Maximum Temperatures.
# - As you move further away from the equator (0°) the temperature starts to decrease, indicating that the highest temperatures recorded are in cities around a 0° latitude which is near the equator.

# %% [markdown]
# ### • Latitude vs. Humidity (%)

# %%
#Plot & Format Data 
plt.scatter(weather_dict["Lat"], weather_dict["Humidity"], facecolor = "mediumseagreen", edgecolor = "darkslategrey")

#Set All Labels
#Title
plt.title("City Latitude vs. Humidity(%)")
#X Axis
plt.xlabel("City Latitude")
#Y Axis
plt.ylabel("Humidity(%)")

#Insert Gridlines
plt.grid(linestyle=":", linewidth=1, alpha=0.5)

#Save Graph as Image (PNG)
plt.savefig('../Images/Lat_VS_Humidity.png')

# %% [markdown]
# #### Observations
# ##### This graph is observing the relationship between City Latitude and Humidity Percentages.
# - It seems that higher latitudes - the northern hemisphere - has more diverse percentages of humidity. There is more of a range of temperature, whereas cities with lower latitudes - the southern hemisphere - contain mostly a humidity percentage above 60% and did not see any humidity below about 30%.

# %% [markdown]
# ### • Latitude vs. Cloudiness (%)

# %%
#Plot & Format Data
plt.scatter(weather_dict["Lat"], weather_dict["Cloudiness"], facecolor = "mediumseagreen", edgecolor = "darkslategrey")

#Set All Labels
#Title
plt.title("City Latitude vs. Cloudiness")
#X Axis
plt.xlabel("City Latitude")
#Y Axis
plt.ylabel("Cloudiness")

#Insert Gridlines
plt.grid(linestyle=":", linewidth=1, alpha=0.5)

#Save Graph as Image (PNG)
plt.savefig('../Images/Lat_VS_Cloudiness.png')

# %% [markdown]
# #### Observations
# ##### This graph is observing the relationship between City Latitude and Cloudiness Percentages.
# - Though the plots for Lat x Cloudiness appear to be mostly scattered, you can see that the plots are less dense in the mid ranges of cloudiness (30% - 70%) while more extreme percentages (indicating no clouds or complete clouds) are more dense.

# %% [markdown]
# ### • Latitude vs. Wind Speed (mph)

# %%
#Plot & Format Data
plt.scatter(weather_dict["Lat"], weather_dict["Wind Speed"], facecolor = "mediumseagreen", edgecolor = "darkslategrey")

#Set All Labels
#Title
plt.title("City Latitude vs. Wind Speed")
#X Axis
plt.xlabel("City Latitude")
#Y Axis
plt.ylabel("Wind Speed")

#Insert Gridlines
plt.grid(linestyle=":", linewidth=1, alpha=0.5)

#Save Graph as Image (PNG)
plt.savefig('../Images/Lat_VS_Wind.png')

# %% [markdown]
# #### Observations
# ##### This graph is observing the relationship between City Latitude and Wind Speed in MPH.
# - Wind speeds do not have a large variation across cities with different latitudes, however do seem to be increasing slightly as latitude increases.
# - Wind speeds of 0-10 mph is most common across all cities, non-dependant of latitude.

# %% [markdown]
# # Complete Linear Regression

# %% [markdown]
# ### Complete Linear Regression Plots for the Following Metrics:
# • Northern Hemisphere - Latitude vs. Temperature (F) <br>
# • Southern Hemisphere - Latitude vs. Temperature (F) <br>
# • Northern Hemisphere - Latitude vs. Humidity (%) <br>
# • Southern Hemisphere - Latitude vs. Humidity (%) <br>
# • Northern Hemisphere - Latitude vs. Cloudiness (%) <br>
# • Southern Hemisphere - Latitude vs. Cloudiness (%) <br>
# • Northern Hemisphere - Latitude vs. Wind Speed (mph) <br>
# • Southern Hemisphere - Latitude vs. Wind Speed (mph) <br>

# %% [markdown]
# ## Create DFs for Northern & Southern Hemispheres

# %%
# Define what north & south hemispheres are / tell the code that the North Hemisphere is anything below or equal to 0, and anything below 0 is in the South Hemisphere
north_hemi = weather_dict.loc[weather_dict["Lat"] >= 0]
south_hemi = weather_dict.loc[weather_dict["Lat"] < 0]

# %% [markdown]
# ## Create New Scatter Plots with Regression

# %% [markdown]
# ### • Northern Hemisphere - Latitude vs. Temperature (F)

# %%
# Add the linear regression equation and line to plot

x_values = north_hemi["Lat"]
y_values = north_hemi["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"
plt.scatter(x_values, y_values, facecolor = "mediumseagreen", edgecolor = "darkslategrey")
plt.plot(x_values, regress_values, "r-", color="midnightblue")
plt.annotate(line_eq,(6,10),fontsize=15, color="midnightblue")

#-------------------------------------------------------------------
#Formatting

plt.title("Northern Hemisphere vs. Max Temp Linear Regression")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()
print(f"The r-value is: {round(rvalue, 2)}")

plt.savefig('../Images/NHemi_Lat_VS_Temp.png')
# Out:
# The r-value is: -0.88

# %% [markdown]
# #### Observations
# ##### This graph is observing the relationship between City Latitude and Maximum Temperature (F°) of the Northern Hemisphere
# - There is a direct correlation between Latitude and Temperature, with the scatter plot indicating that as the latitude increases the maximum temperature decreases. I.e. Cities near the equator (°) are more likely to see a very high max temperature while cities in the most North regions (highest latitude #s) are more likely to see a lower maximum temperature.

# %% [markdown]
# ### • Southern Hemisphere - Latitude vs. Temperature (F)

# %%
# Add the linear regression equation and line to plot

x_values = south_hemi["Lat"]
y_values = south_hemi["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"
plt.scatter(x_values, y_values, facecolor = "mediumseagreen", edgecolor = "darkslategrey")
plt.plot(x_values, regress_values, "r-", color="midnightblue")
plt.annotate(line_eq,(-40,50),fontsize=15, color="midnightblue")

#-------------------------------------------------------------------
#Formatting

plt.title("Southern Hemisphere vs. Max Temp Linear Regression")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()
print(f"The r-value is: {round(rvalue, 2)}")

plt.savefig('../Images/SHemi_Lat_VS_Temp.png')
# Out:
# The r-value is: 0.69

# %% [markdown]
# #### Observations
# ##### This graph is observing the relationship between City Latitude and Maximum Temperature (F°) of the Southern Hemisphere
# - There is a direct correlation between Latitude and Temperature, with the scatter plot indicating that as the latitude increases the maximum temperature decreases. The regression model is very obviously linear, showcasing a direct relationship between the two measurements.
# - Cities near the equator (°) are more likely to see a very high max temperature while cities in the most South regions (the lowest latitude #s) are more likely to see a lower maximum temperature, though not quite as cold as what we saw in the Northern Hemisphere.

# %% [markdown]
# ### • Northern Hemisphere - Latitude vs. Humidity (%)

# %%
# Add the linear regression equation and line to plot

x_values = north_hemi["Lat"]
y_values = north_hemi["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"
plt.scatter(x_values, y_values, facecolor = "mediumseagreen", edgecolor = "darkslategrey")
plt.plot(x_values, regress_values, "r-", color="midnightblue")
plt.annotate(line_eq,(44,10),fontsize=15, color="midnightblue")

#-------------------------------------------------------------------
#Formatting

plt.title("N. Hemisphere - Latitude vs. Humidity , Linear Regression")
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()
print(f"The r-value is: {round(rvalue, 2)}")

plt.savefig('../Images/NHemi_Lat_VS_Humidity.png')
# Out:
# The r-value is: 0.24

# %% [markdown]
# ### • Southern Hemisphere - Latitude vs. Humidity (%)

# %%
# Add the linear regression equation and line to plot

x_values = south_hemi["Lat"]
y_values = south_hemi["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"
plt.scatter(x_values, y_values, facecolor = "mediumseagreen", edgecolor = "darkslategrey")
plt.plot(x_values, regress_values, "r-", color="midnightblue")
plt.annotate(line_eq,(-55, 35),fontsize=15, color="midnightblue")

#-------------------------------------------------------------------
#Formatting

plt.title("S. Hemisphere - Latitude vs. Humidity , Linear Regression")
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()
print(f"The r-value is: {round(rvalue, 2)}")

plt.savefig('../Images/SHemi_Lat_VS_Humidity.png')
# Out:
# The r-value is: 0.1

# %% [markdown]
# #### Observations
# ##### The above two graphs are observing the relationship between City Latitude and Humidity (%). The first represents the Northern Hemisphere while the second represents the Southern Hemisphere.
#
# - Though not extremely strong, there is a correlation between Latitude and Humidity in both hemispheres. The scatter plot and linear regression model indicates as you get higher in latitude, humidy also increases. In this case it would have been hard to determine the relationship of the two measurements without the regression model, but our line of best fit clearly shows an increase in each measurement moving together in correspondance.

# %% [markdown]
# ### •Northern Hemisphere - Latitude vs. Cloudiness (%)

# %%
# Add the linear regression equation and line to plot

x_values = north_hemi["Lat"]
y_values = north_hemi["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"
plt.scatter(x_values, y_values, facecolor = "mediumseagreen", edgecolor = "darkslategrey")
plt.plot(x_values, regress_values, "r-", color="midnightblue")
plt.annotate(line_eq,(45, 50),fontsize=15, color="midnightblue")

#-------------------------------------------------------------------
#Formatting

plt.title("N. Hemisphere - Latitude vs. Cloudiness , Linear Regression")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()
print(f"The r-value is: {round(rvalue, 2)}")

plt.savefig('../Images/NHemi_Lat_VS_Cloudiness.png')
# Out:
# The r-value is: 0.17

# %% [markdown]
# ### •Southern Hemisphere - Latitude vs. Cloudiness (%)

# %%
# Add the linear regression equation and line to plot

x_values = south_hemi["Lat"]
y_values = south_hemi["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"
plt.scatter(x_values, y_values, facecolor = "mediumseagreen", edgecolor = "darkslategrey")
plt.plot(x_values, regress_values, "r-", color="midnightblue")
plt.annotate(line_eq,(-48, 53),fontsize=15, color="midnightblue")

#-------------------------------------------------------------------
#Formatting

plt.title("S. Hemisphere - Latitude vs. Cloudiness , Linear Regression")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.xlim(-50, 0)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.show()
print(f"The r-value is: {round(rvalue, 2)}")

plt.savefig('../Images/SHemi_Lat_VS_Cloudiness.png')
# Out:
# The r-value is: 0.19

# %% [markdown]
# #### Observations
# ##### The above two graphs are observing the relationship between City Latitude and Cloudiness (%). The first represents the Northern Hemisphere while the second represents the Southern Hemisphere.
#
# - The linear regression model is positive and indicates a solid relationship between Latitude and Cloudiness. Though the plots seem scattered they actually show a positive increase, indicating that as latitude increases the percent of cloudiness also increases. This same trend happens in both hemispheres, indicating that the equator isn't really a significant factor but rather how high or low of a lattitude the city sits on.

# %% [markdown]
# ### •Northern Hemisphere -  Latitude vs. Wind Speed (mph)

# %%
# Add the linear regression equation and line to plot

x_values = north_hemi["Lat"]
y_values = north_hemi["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"
plt.scatter(x_values, y_values, facecolor = "mediumseagreen", edgecolor = "darkslategrey")
plt.plot(x_values, regress_values, "r-", color="midnightblue")
plt.annotate(line_eq,(5, 20),fontsize=15, color="midnightblue")

#-------------------------------------------------------------------
#Formatting

plt.title("N. Hemisphere - Latitude vs. Wind Speed , Linear Regression")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (MPH)')
plt.ylim(0, 25)
plt.xlim(0, 75)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()
print(f"The r-value is: {round(rvalue, 2)}")

plt.savefig('../Images/NHemi_Lat_VS_Wind.png')
# Out:
# The r-value is: 0.12

# %% [markdown]
# ### •Southern Hemisphere - Latitude vs. Wind Speed (mph)

# %%
# Add the linear regression equation and line to plot

x_values = south_hemi["Lat"]
y_values = south_hemi["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"
plt.scatter(x_values, y_values, facecolor = "mediumseagreen", edgecolor = "darkslategrey")
plt.plot(x_values, regress_values, "r-", color="midnightblue")
plt.annotate(line_eq,(-48, 17),fontsize=15, color="midnightblue")
#-------------------------------------------------------------------
#Formatting

plt.title("S. Hemisphere - Latitude vs. Wind Speed , Linear Regression")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (MPH)')
plt.xlim(-50, 0)
plt.ylim(0, 25)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.show()

#Show what the R-Value is
print(f"The r-value is: {round(rvalue, 2)}")

plt.savefig('../Images/SHemi_Lat_VS_Wind.png')
# Out:
# The r-value is: -0.08

# %% [markdown]
# #### Observations
# ##### The two graphs above are observing the relationship between City Latitude and Wind Speed (MPH). The first represents the Northern Hemisphere while the second represents the Southern Hemisphere.
#
# - These two scatter plots and their regression models indicate that wind speed is at it's lowest speed while near the equator. As you move farther away in both North and South directions, wind speed increases very gradually. You can see proof of this with a positive slope in the Northern Hemisphere and a negative slope in the Southern Hemisphere - the lowest point of wind speed is at the equator (0°).
