# %% [markdown]
# # Dependencies

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st

# import API key
from config import API_Key

#Import citipy to collect latitude and longitudes of cities
from citipy import citipy

# Output File (CSV)
Output_Data_file = "../Output_Data/cities.csv"

# %% [markdown]
# # Create Randomized Cities List

# %%
# Set the ranges the latitude and longitudes
latitude_range = (-90, 90)
longitude_range = (-180, 180)

#Create holding placements for the cordinates and the cities you're making
coordinates = []
cities = []

#Set ranges for coordinates you generate
lat = np.random.uniform(low=-90.000, high=90.000, size=1500)
lng = np.random.uniform(low=-180.000, high=180.000, size=1500)
coordinates = zip(lat, lng)

# %%
#Connect the coordinates to the cities they match with
for coordinate in coordinates: 
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
     
    #sub in 20% to replace any spaces in the URL so it runs correctly
    city = city.replace(" ", "20%")
    
    #Remove duplicates = if the city is not duplicated add it to the list
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 619

# %%
#Start the URL for the Weather Map API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + API_Key

# %%
#Create lists to add the API data into
city_name = []
country = []
date = []
lat = []
lng = []
cloudiness = []
humidity = []
max_temp = []
wind_speed = []

# %% [markdown]
# # Create a For Loop to Pull Data for Each City
# ### (API Calls)

# %%
#API call counter
api_call_count = 1

#Display counter
print("------------------------------------")
print("Grabbing your info now! Please hold.")
print("------------------------------------")

#Go through the cities in the list and get the API data to fill
for city in cities:
    try: 
        response = requests.get(f"{url}&q={city}").json()
        
        city_name.append(response["name"])
        
        cloudiness.append(response["clouds"]["all"])
        
        country.append(response["sys"]["country"])
        
        date.append(response["dt"])
        
        humidity.append(response["main"]["humidity"])
        
        max_temp.append(response["main"]["temp_max"])
        
        lat.append(response["coord"]["lat"])
        
        lng.append(response["coord"]["lon"])
        
        wind_speed.append(response["wind"]["speed"])
        
        city_record = response["name"]
        
        print(f"Record {api_call_count}: {city_record}")
   

        #Add one to counter to make it cycle through for loop
        api_call_count= api_call_count + 1
    
        #Insert pace to the API calls so we don't get kicked out/banned
        time.sleep(1.01)
    
    
    #If there is no city, skip the line and go to the next one
    except:
        print("No city found for that listing. Moving onto the next.")
    continue
    
    print("-----------------------------")
    print("Data Retrieval Complete")
    print("-----------------------------")
# Out:
# ------------------------------------
# Grabbing your info now! Please hold.
# ------------------------------------
# Record 1: Atuona
# Record 2: Bluff
# No city found for that listing. Moving onto the next.
# Record 3: Tiksi
# No city found for that listing. Moving onto the next.
# Record 4: Albany
# Record 5: Chui
# No city found for that listing. Moving onto the next.
# Record 6: Shelton
# Record 7: Juneau
# No city found for that listing. Moving onto the next.
# Record 8: Severo-Kuril'sk
# Record 9: Lüderitz
# Record 10: Jamestown
# Record 11: Aswān
# Record 12: Marsabit
# Record 13: Vaini
# Record 14: Ushuaia
# No city found for that listing. Moving onto the next.
# Record 15: Mpika
# Record 16: Fortuna
# Record 17: Tasiilaq
# No city found for that listing. Moving onto the next.
# Record 18: Hobart
# No city found for that listing. Moving onto the next.
# Record 19: Kapaa
# Record 20: Aklavik
# Record 21: Banjar
# No city found for that listing. Moving onto the next.
# Record 22: Kununurra
# Record 23: Alamosa
# Record 24: Venice
# Record 25: Dingle
# No city found for that listing. Moving onto the next.
# Record 26: Ranau
# Record 27: Castro
# Record 28: Ahipara
# Record 29: Thompson
# Record 30: Yekimovichi
# Record 31: Souillac
# Record 32: Saint Paul Harbor
# Record 33: Hong Kong
# No city found for that listing. Moving onto the next.
# No city found for that listing. Moving onto the next.
# Record 34: Rikitea
# Record 35: Butaritari
# No city found for that listing. Moving onto the next.
# Record 36: Hermanus
# Record 37: Zhangjiakou
# No city found for that listing. Moving onto the next.
# Record 38: Diffa
# Record 39: Pisco
# Record 40: Lander
# Record 41: Esperance
# Record 42: Cabinda
# Record 43: Salalah
# Record 44: Upernavik
# Record 45: Svetlaya
# Record 46: Teya
# Record 47: Busselton
# Record 48: Kulhudhuffushi
# Record 49: Kavieng
# No city found for that listing. Moving onto the next.
# Record 50: Kashgar
# Record 51: Geraldton
# Record 52: Provideniya
# Record 53: Bama
# Record 54: Narsaq
# Record 55: Miraflores
# Record 56: Popondetta
# Record 57: Assiut
# No city found for that listing. Moving onto the next.
# No city found for that listing. Moving onto the next.
# Record 58: Cañar
# Record 59: Caravelas
# Record 60: Kruisfontein
# Record 61: Sandwick
# Record 62: Praia
# Record 63: Kahului
# Record 64: Stromness
# No city found for that listing. Moving onto the next.
# Record 65: Yellowknife
# Record 66: Cidreira
# Record 67: Tuatapere
# No city found for that listing. Moving onto the next.
# Record 68: Antalaha
# Record 69: Darhan
# No city found for that listing. Moving onto the next.
# Record 70: Pangnirtung
# No city found for that listing. Moving onto the next.
# Record 71: Vikindu
# Record 72: Yangi Marg`ilon
# No city found for that listing. Moving onto the next.
# Record 73: Mahébourg
# Record 74: Changchun
# Record 75: Padang
# Record 76: Dunedin
# Record 77: Genhe
# Record 78: Iqaluit
# Record 79: Tyrma
# Record 80: Oyama
# Record 81: Gōdo
# No city found for that listing. Moving onto the next.
# No city found for that listing. Moving onto the next.
# No city found for that listing. Moving onto the next.
# Record 82: Mataura
# No city found for that listing. Moving onto the next.
# Record 83: Tulagi
# No city found for that listing. Moving onto the next.
# Record 84: Saint-Philippe
# Record 85: Nanortalik
# Record 86: Chabahar
# No city found for that listing. Moving onto the next.
# Record 87: Saint-Augustin
# No city found for that listing. Moving onto the next.
# No city found for that listing. Moving onto the next.
# Record 88: Airai
# No city found for that listing. Moving onto the next.
# No city found for that listing. Moving onto the next.
# Record 89: George Town
# Record 90: Tautira
# Record 91: Honiara
# Record 92: Hasaki
# No city found for that listing. Moving onto the next.
# Record 93: Dikson
# Record 94: Qeshm
# No city found for that listing. Moving onto the next.
# Record 95: Payo
# Record 96: Leh
# Record 97: Huntsville
# No city found for that listing. Moving onto the next.
# No city found for that listing. Moving onto the next.
# Record 98: Zhezkazgan
# Record 99: Waipawa
# Record 100: Petropavlovsk-Kamchatskiy
# No city found for that listing. Moving onto the next.
# No city found for that listing. Moving onto the next.
# Record 101: Pevek
# Record 102: Tsimmerbude
# Record 103: Rognan
# No city found for that listing. Moving onto the next.
# No city found for that listing. Moving onto the next.
# Record 104: Sakakah
# Record 105: Nikolskoye
# Record 106: Alofi
# Record 107: Chokurdakh
# Record 108: Wanaka
# Record 109: Roald
# Record 110: Avarua
# Record 111: Kamina
# No city found for that listing. Moving onto the next.
# Record 112: Bengkulu
# Record 113: Beringovskiy
# Record 114: Sumkino
# Record 115: Mansfield
# Record 116: Nemuro
# Record 117: Yerbogachën
# No city found for that listing. Moving onto the next.
# Record 118: Koulamoutou
# No city found for that listing. Moving onto the next.
# Record 119: Tarakan
# Record 120: Mossamedes
# Record 121: Hithadhoo
# Record 122: Araxá
# Record 123: Itaituba
# Record 124: Guder
# Record 125: Votkinsk
# Record 126: Mayo
# Record 127: Inhambane
# Record 128: Katsuura
# Record 129: Cururupu
# Record 130: Huarmey
# Record 131: Constitución
# Record 132: Neryungri
# Record 133: Izazi
# Record 134: Carnot
# Record 135: Sørland
# Record 136: Nuuk
# Record 137: Bremerton
# Record 138: Ust'-Ishim
# Record 139: Kabanjahe
# Record 140: Sept-Îles
# Record 141: Saint-Louis
# Record 142: Hofn
# Record 143: Cartagena
# Record 144: Torbay
# Record 145: Lata
# Record 146: Dicabisagan
# No city found for that listing. Moving onto the next.
# Record 147: Nador
# Record 148: Giresun Province
# Record 149: Siniscola
# Record 150: Bubaque
# No city found for that listing. Moving onto the next.
# Record 151: Bredasdorp
# Record 152: Mongo
# Record 153: Kampot
# Record 154: Athabasca
# Record 155: Pangody
# No city found for that listing. Moving onto the next.
# Record 156: Mirny
# No city found for that listing. Moving onto the next.
# Record 157: Sobolevo
# Record 158: Qaanaaq
# Record 159: Vardø
# Record 160: Mugur-Aksy
# Record 161: Aksarka
# Record 162: Merauke
# Record 163: Wonthaggi
# Record 164: Durango
# Record 165: Eyrarbakki
# Record 166: Almaznyy
# No city found for that listing. Moving onto the next.
# Record 167: Longyearbyen
# Record 168: Distrikt Brokopondo
# Record 169: Markivka
# Record 170: Rajaori
# Record 171: Husavik
# Record 172: Hornepayne
# No city found for that listing. Moving onto the next.
# Record 173: Bethel
# Record 174: Haverfordwest
# Record 175: Priargunsk
# Record 176: Suvorov
# Record 177: Naze
# Record 178: Ulaangom
# Record 179: Hilo
# Record 180: Osorno
# Record 181: Aras
# No city found for that listing. Moving onto the next.
# Record 182: Olafsvik
# Record 183: Chernyshevskiy
# Record 184: Carnarvon
# Record 185: Codrington
# No city found for that listing. Moving onto the next.
# Record 186: Xiongzhou
# Record 187: Dno
# Record 188: Bundaberg
# Record 189: Udachny
# Record 190: Cherskiy
# Record 191: Tazovsky
# Record 192: Watertown
# No city found for that listing. Moving onto the next.
# No city found for that listing. Moving onto the next.
# Record 193: Tuktoyaktuk
# No city found for that listing. Moving onto the next.
# Record 194: Saldanha
# Record 195: Sydney
# No city found for that listing. Moving onto the next.
# Record 196: Nome
# Record 197: Doka
# Record 198: Lodja
# Record 199: Skegness
# Record 200: Bonnyville
# Record 201: Kumul
# No city found for that listing. Moving onto the next.
# Record 202: Coyhaique
# Record 203: Faanui
# No city found for that listing. Moving onto the next.
# Record 204: Portland
# Record 205: Poum
# No city found for that listing. Moving onto the next.
# Record 206: Lorengau
# No city found for that listing. Moving onto the next.
# No city found for that listing. Moving onto the next.
# No city found for that listing. Moving onto the next.
# Record 207: Bureya
# Record 208: Pascagoula
# Record 209: Øksfjord
# No city found for that listing. Moving onto the next.
# Record 210: Khatanga
# Record 211: Skibotn
# Record 212: Wonosari
# Record 213: Bereda
# Record 214: Katobu
# Record 215: Ucluelet
# Record 216: Tual
# Record 217: Kenai
# Record 218: Pitkyaranta
# Record 219: Coquimbo
# Record 220: Anjozorobe
# Record 221: Mana
# Record 222: Isangel
# Record 223: Kailua
# Record 224: Deputatsky
# Record 225: Rocha
# No city found for that listing. Moving onto the next.
# No city found for that listing. Moving onto the next.
# No city found for that listing. Moving onto the next.
# Record 226: Birin
# Record 227: Montepuez
# Record 228: Pringsewu
# Record 229: St. George's
# Record 230: Gao
# Record 231: Vinh
# Record 232: Zabid
# Record 233: Kaitangata
# Record 234: Stokmarknes
# Record 235: Bulawayo
# Record 236: Republic
# No city found for that listing. Moving onto the next.
# Record 237: Bjørnevatn
# Record 238: Abhā
# Record 239: Burgeo
# Record 240: Tessalit
# No city found for that listing. Moving onto the next.
# Record 241: Mucurapo
# No city found for that listing. Moving onto the next.
# Record 242: Ketchikan
# No city found for that listing. Moving onto the next.
# Record 243: Laureles
# Record 244: Mwinilunga
# No city found for that listing. Moving onto the next.
# Record 245: Sabzawār
# Record 246: Biak
# Record 247: Jalu
# Record 248: Beloha
# No city found for that listing. Moving onto the next.
# Record 249: Isiro
# Record 250: Baihar
# Record 251: Ust'-Kut
# Record 252: Belmonte
# Record 253: Centreville
# Record 254: Tashtagol
# Record 255: Korla
# No city found for that listing. Moving onto the next.
# Record 256: Gornopravdinsk
# Record 257: Namatanai
# Record 258: Elban
# No city found for that listing. Moving onto the next.
# Record 259: Lagunas
# Record 260: Verkhoyansk
# No city found for that listing. Moving onto the next.
# Record 261: Barrow
# Record 262: Bilibino
# No city found for that listing. Moving onto the next.
# Record 263: Nushki
# Record 264: Rudnogorsk
# Record 265: Kemijärvi
# Record 266: Bontang
# No city found for that listing. Moving onto the next.
# No city found for that listing. Moving onto the next.
# Record 267: Örnsköldsvik
# Record 268: Alekseyevka
# Record 269: Tokur
# Record 270: Talcahuano
# Record 271: Manta
# Record 272: Ilhabela
# Record 273: Vicksburg
# Record 274: Mareeba
# No city found for that listing. Moving onto the next.
# Record 275: Melfi
# Record 276: Sitka
# Record 277: Vestmannaeyjar
# Record 278: Pandan
# Record 279: Muros
# Record 280: Changji
# Record 281: Riyadh
# Record 282: Muroran
# Record 283: Xining
# Record 284: Kamaishi
# No city found for that listing. Moving onto the next.
# Record 285: Sapele
# No city found for that listing. Moving onto the next.
# No city found for that listing. Moving onto the next.
# Record 286: Yeppoon
# No city found for that listing. Moving onto the next.
# Record 287: Adrar
# No city found for that listing. Moving onto the next.
# Record 288: Broome
# No city found for that listing. Moving onto the next.
# No city found for that listing. Moving onto the next.
# Record 289: Amahai
# Record 290: Colombo
# Record 291: Lagoa
# Record 292: Sur
# Record 293: Acapulco de Juárez
# Record 294: Rūdsar
# Record 295: Kargasok
# Record 296: Callaway
# Record 297: Pangkalanbuun
# Record 298: Nantucket
# No city found for that listing. Moving onto the next.
# Record 299: Hokitika
# No city found for that listing. Moving onto the next.
# Record 300: Taoudenni
# Record 301: Mafinga
# Record 302: Yar-Sale
# Record 303: Itarema
# No city found for that listing. Moving onto the next.
# No city found for that listing. Moving onto the next.
# Record 304: Ondjiva
# No city found for that listing. Moving onto the next.
# Record 305: Nokaneng
# Record 306: Yārāda
# Record 307: Laas
# No city found for that listing. Moving onto the next.
# Record 308: Bonthe
# Record 309: Cayenne
# No city found for that listing. Moving onto the next.
# No city found for that listing. Moving onto the next.
# Record 310: Dvinskoy Bereznik
# Record 311: Heraclea
# Record 312: Kralendijk
# Record 313: Manat
# Record 314: Aden
# Record 315: Saskylakh
# Record 316: Westport
# Record 317: Inuvik
# Record 318: Lebu
# Record 319: Kidal
# Record 320: Trenggalek
# Record 321: Tiarei
# Record 322: Lavrentiya
# Record 323: Leningradskiy
# No city found for that listing. Moving onto the next.
# Record 324: Polunochnoye
# Record 325: Bathsheba
# Record 326: Darnah
# Record 327: Champerico
# Record 328: Yekaterinogradskaya
# Record 329: Zhicheng
# Record 330: Jianning
# Record 331: Ugoofaaru
# No city found for that listing. Moving onto the next.
# Record 332: Kirakira
# Record 333: Neiafu
# Record 334: Pecos
# Record 335: Necochea
# Record 336: Egvekinot
# Record 337: Cabadiangan
# Record 338: Omsk
# No city found for that listing. Moving onto the next.
# Record 339: Batagay-Alyta
# Record 340: Mendi
# Record 341: Bagdarin
# Record 342: Ilulissat
# Record 343: Yabassi
# Record 344: Arman'
# Record 345: Klaksvík
# Record 346: Ust-Nera
# Record 347: Zhigansk
# Record 348: Vikhorevka
# Record 349: Kingston
# Record 350: Tomatlán
# Record 351: Esmeraldas
# Record 352: Sawākin
# Record 353: Kollegāl
# Record 354: Ibrā’
# No city found for that listing. Moving onto the next.
# Record 355: Paamiut
# Record 356: Talnakh
# Record 357: Cascais
# Record 358: Shenzhen
# Record 359: Clovis
# No city found for that listing. Moving onto the next.
# Record 360: Barcelos
# Record 361: Tagusao
# No city found for that listing. Moving onto the next.
# No city found for that listing. Moving onto the next.
# Record 362: Greenville
# Record 363: Kiryat Gat
# Record 364: Esso
# Record 365: Sovetskiy
# Record 366: Kavaratti
# No city found for that listing. Moving onto the next.
# Record 367: Balkhash
# Record 368: Noumea
# Record 369: Sidrolândia
# No city found for that listing. Moving onto the next.
# No city found for that listing. Moving onto the next.
# Record 370: Imbituba
# No city found for that listing. Moving onto the next.
# Record 371: Shimoda
# Record 372: Kawalu
# Record 373: Chililabombwe
# Record 374: Zyryanovsk
# No city found for that listing. Moving onto the next.
# Record 375: Mumford
# No city found for that listing. Moving onto the next.
# Record 376: Chānda
# Record 377: Kargopol'
# Record 378: Buchanan
# Record 379: Marawi
# No city found for that listing. Moving onto the next.
# Record 380: Heishan
# No city found for that listing. Moving onto the next.
# Record 381: Buhe
# Record 382: Tongliao
# No city found for that listing. Moving onto the next.
# Record 383: Lompoc
# Record 384: Tucumcari
# Record 385: Kitimat
# Record 386: Kilindoni
# No city found for that listing. Moving onto the next.
# Record 387: Bumba
# Record 388: Léo
# Record 389: Olinda
# No city found for that listing. Moving onto the next.
# Record 390: Birao
# No city found for that listing. Moving onto the next.
# Record 391: Atikokan
# No city found for that listing. Moving onto the next.
# Record 392: Gulu
# Record 393: Tekirdağ
# Record 394: Härnösand
# Record 395: Wahpeton
# Record 396: Iracoubo
# Record 397: Srostki
# Record 398: Brae
# Record 399: Tupik
# No city found for that listing. Moving onto the next.
# Record 400: Jinotega
# No city found for that listing. Moving onto the next.
# Record 401: Qaqortoq
# Record 402: Mogadishu
# Record 403: Staszów
# Record 404: Saint-Pierre
# No city found for that listing. Moving onto the next.
# Record 405: Caceres
# Record 406: Chiredzi
# Record 407: Maragogi
# Record 408: Healdsburg
# Record 409: Dzheyrakh
# Record 410: Ossora
# Record 411: Wajir
# Record 412: Poso
# Record 413: Makat
# Record 414: Ostrovnoy
# Record 415: Hambantota
# Record 416: Arys
# Record 417: Tambacounda
# Record 418: Karacabey
# Record 419: Adré
# No city found for that listing. Moving onto the next.
# No city found for that listing. Moving onto the next.
# Record 420: Kaseda-shirakame
# Record 421: Horki
# Record 422: Blytheville
# Record 423: Kisangani
# Record 424: Zaysan
# No city found for that listing. Moving onto the next.
# Record 425: Tutóia
# Record 426: Carroll
# Record 427: Bemidji
# Record 428: Funadhoo
# No city found for that listing. Moving onto the next.
# Record 429: Rome
# No city found for that listing. Moving onto the next.
# No city found for that listing. Moving onto the next.
# Record 430: Zyryanskoye
# No city found for that listing. Moving onto the next.
# Record 431: Mackay
# No city found for that listing. Moving onto the next.
# Record 432: Churapcha
# Record 433: Prescott
# Record 434: Sharkan
# Record 435: Taksimo
# Record 436: Eyl
# Record 437: Sechura
# Record 438: Malé
# Record 439: Aykhal
# Record 440: Banff
# Record 441: Amapá
# Record 442: Gizel’
# Record 443: Sambava
# Record 444: Mapiri
# Record 445: Okha
# No city found for that listing. Moving onto the next.
# Record 446: Saint-François
# Record 447: Hualmay
# Record 448: Harper
# No city found for that listing. Moving onto the next.
# Record 449: Yangambi
# Record 450: Ust'-Kulom
# Record 451: Ancud
# No city found for that listing. Moving onto the next.
# No city found for that listing. Moving onto the next.
# Record 452: Mabaruma
# Record 453: Altamira
# Record 454: Segezha
# Record 455: Dingli
# Record 456: Sarkand
# Record 457: Dolores
# Record 458: Constantine
# Record 459: Leshukonskoye
# Record 460: Yokadouma
# Record 461: Osmeña
# Record 462: Maun
# Record 463: Port-Gentil
# Record 464: Ankang
# Record 465: Vanavara
# Record 466: Podyuga
# Record 467: Suntar
# Record 468: Acarí
# Record 469: Ishigaki
# Record 470: Anadyr
# Record 471: Taganak
# Record 472: Agapovka
# Record 473: Salym
# No city found for that listing. Moving onto the next.
# Record 474: Nishihara
# No city found for that listing. Moving onto the next.
# Record 475: Baiyin
# Record 476: Dali
# Record 477: Kumluca
# Record 478: Gangāpur
# No city found for that listing. Moving onto the next.
# Record 479: Paramonga
# Record 480: Oranjemund
# Record 481: Nebyliv
# Record 482: Catu
# No city found for that listing. Moving onto the next.
# Record 483: Yakeshi
# Record 484: Dovbysh
# Record 485: Lazarev
# No city found for that listing. Moving onto the next.
# Record 486: Palāsa
# Record 487: Yunyang

# %% [markdown]
# # Turn Data from API into a DF

# %%
#Have to do this in order to populate scatter plots

# %%
weather_df = pd.DataFrame({"City": city_name,
                             "Cloudiness": cloudiness,
                             "Country": country,
                             "Humidity": humidity,
                             "Lat": lat,
                             "Lng": lng,
                             "Max Temp": max_temp,
                             "Wind Speed": wind_speed})

# %%
#Display Dict as DF
weather_dict.head()
# Out:
#          City  Cloudiness Country Date  Humidity      Lat       Lng  Max Temp  \
# 0   Concordia          40      AR  NaT        48 -31.3930  -58.0209     84.20
# 1    Bengkulu         100      ID  NaT        81  -3.8004  102.2655     77.32
# 2  Butaritari         100      KI  NaT        80   3.0707  172.7902     81.81
# 3    Ilhabela          60      BR  NaT        81 -23.7781  -45.3581     75.06
# 4      Cairns          90      AU  NaT        88 -16.9167  145.7667     75.20
#
#    Wind Speed
# 0        4.61
# 1        9.98
# 2       14.88
# 3        5.68
# 4        5.75

# %%
# Save city data into a csv file
#weather_dict.to_csv("Output_Data/cities.csv", index = False)

# %% [markdown]
# # Create Scatter Plots & Plot Data

# %%
#We will be creating scatter plots to represent the following data
# -Temperature (F) vs. Latitude
# -Humidity (%) vs. Latitude
# -Cloudiness (%) vs. Latitude
# -Wind Speed (mph) vs. Latitude

# %% [markdown]
# ### Temperature (F) vs. Latitude

# %%
#Plot & Format Data
plt.scatter(weather_dict["Lat"], weather_dict["Max Temp"], facecolor = "mediumseagreen", edgecolor = "darkslategrey")

#Set All Labels
#Title
plt.title("City Latitude vs. Max Temperature")
#X Axis
plt.xlabel("Max Temperature (F)")
#Y Axis
plt.ylabel("City Latitude")

#Insert Gridlines
plt.grid(linestyle=":", linewidth=1, alpha=0.5)

# %% [markdown]
# #### Observations
#
# -

# %% [markdown]
# ### Humidity (%) vs. Latitude

# %%
#Plot & Format Data
plt.scatter(weather_dict["Lat"], weather_dict["Humidity"], facecolor = "mediumseagreen", edgecolor = "darkslategrey")

#Set All Labels
#Title
plt.title("City Latitude vs. Humidity(%)")
#X Axis
plt.xlabel("Humidity (F)")
#Y Axis
plt.ylabel("City Latitude")

#Insert Gridlines
plt.grid(linestyle=":", linewidth=1, alpha=0.5)

# %% [markdown]
# #### Observations
#
# -

# %% [markdown]
# ### Cloudiness (%) vs. Latitude

# %%
#Plot & Format Data
plt.scatter(weather_dict["Lat"], weather_dict["Cloudiness"], facecolor = "mediumseagreen", edgecolor = "darkslategrey")

#Set All Labels
#Title
plt.title("City Latitude vs. Cloudiness")
#X Axis
plt.xlabel("Cloudiness")
#Y Axis
plt.ylabel("City Latitude")

#Insert Gridlines
plt.grid(linestyle=":", linewidth=1, alpha=0.5)

# %% [markdown]
# ### Wind Speed (mph) vs. Latitude

# %%
#Plot & Format Data
plt.scatter(weather_dict["Lat"], weather_dict["Wind Speed"], facecolor = "mediumseagreen", edgecolor = "darkslategrey")

#Set All Labels
#Title
plt.title("City Latitude vs. Wind Speed")
#X Axis
plt.xlabel("Wind Speed")
#Y Axis
plt.ylabel("City Latitude")

#Insert Gridlines
plt.grid(linestyle=":", linewidth=1, alpha=0.5)
